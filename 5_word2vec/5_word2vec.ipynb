# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5244, 3081, 12, 6, 195, 2, 3134, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['as', 'anarchism', 'a', 'originated', 'term', 'as', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['anarchism', 'a', 'originated', 'term', 'originated', 'as', 'of', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=embed,
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keepdims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.global_variables_initializer().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.866239
# Nearest to seven: collaborations, directives, seinfeld, byzantine, gerda, contras, crickets, hamburg,
# Nearest to also: eug, workaround, celibacy, kurukshetra, egyptologists, atlantean, cavalcanti, uncover,
# Nearest to they: bioleaching, claws, kwajalein, sara, darius, capcom, brace, informants,
# Nearest to about: suprarenal, loup, unambiguously, knocking, depth, internal, dobbs, seti,
# Nearest to most: baccalaureate, deflect, rhyme, alphonso, astonishing, contractions, sternberg, defence,
# Nearest to by: intentionally, pnh, poetess, oil, factbook, resuming, tentatively, meaning,
# Nearest to state: initiation, latency, keen, crocodile, refund, fairy, heel, tribunals,
# Nearest to from: simplest, sculpture, cautionary, dicotyledons, merton, rationally, cistercians, fared,
# Nearest to d: masonic, dwyer, guernsey, ladders, christendom, affects, vpi, blyton,
# Nearest to no: himalayan, alexandra, freie, vigilante, impediment, breezes, extras, fellowships,
# Nearest to united: satirised, rashad, nebula, modification, preoccupations, pacified, initials, dispersing,
# Nearest to s: gesta, comprehensive, normalization, commonwealth, masons, spaniard, duffy, orl,
# Nearest to while: subjected, wanderings, brahmagupta, triangles, futurist, mondegreen, doric, reconquered,
# Nearest to six: singularities, fundamentalism, eucharist, representation, schiavo, thereof, tacit, brahmins,
# Nearest to over: walford, gz, olympic, krav, monologues, actor, hypotheses, amount,
# Nearest to five: camels, trumbull, improvement, ust, dentists, babur, temporary, amalric,
# Average loss at step 2000: 4.367715
# Average loss at step 4000: 3.862237
# Average loss at step 6000: 3.790300
# Average loss at step 8000: 3.682449
# Average loss at step 10000: 3.619829
# Nearest to seven: eight, six, nine, five, three, four, zero, two,
# Nearest to also: it, which, generally, often, not, he, marketed, actually,
# Nearest to they: he, not, it, there, elfin, sara, darius, i,
# Nearest to about: drier, bacall, syrian, being, epictetus, roses, internal, knocking,
# Nearest to most: baccalaureate, rhyme, veterinary, mordechai, huis, deflect, easternmost, herbivorous,
# Nearest to by: poetess, was, nominative, as, with, factbook, from, calibers,
# Nearest to state: initiation, heel, latency, faiths, tribunals, mosquito, ferguson, swaim,
# Nearest to from: cautionary, in, simplest, into, by, dicotyledons, cistercians, colored,
# Nearest to d: fjords, dwyer, masonic, blyton, inherit, ladders, brummell, blueprints,
# Nearest to no: impediment, matre, kiesinger, dedekind, prism, brotherhoods, fucked, criticises,
# Nearest to united: nebula, accomplishing, latter, neberg, satirised, dispersing, jen, limb,
# Nearest to s: his, or, and, mcqueen, erich, was, ariosto, tumultuous,
# Nearest to while: subjected, brahmagupta, streamlining, reconquered, mondegreen, triangles, iced, wanderings,
# Nearest to six: eight, four, seven, five, three, nine, zero, two,
# Nearest to over: walford, olympic, monologues, nouveaux, presbyterian, krav, device, try,
# Nearest to five: eight, three, seven, nine, six, zero, four, two,
# Average loss at step 12000: 3.604117
# Average loss at step 14000: 3.572675
# Average loss at step 16000: 3.406601
# Average loss at step 18000: 3.456510
# Average loss at step 20000: 3.542223
# Nearest to seven: six, eight, nine, four, five, three, zero, two,
# Nearest to also: generally, often, which, actually, not, now, then, who,
# Nearest to they: he, there, we, it, not, i, who, often,
# Nearest to about: drier, epictetus, beli, syrian, disappointing, exhorted, bacall, tinbergen,
# Nearest to most: more, huis, veterinary, theological, yorke, rhyme, all, warships,
# Nearest to by: poetess, for, calibers, be, was, in, been, is,
# Nearest to state: initiation, chadian, gerhardt, portrays, subsidence, calibre, montt, city,
# Nearest to from: into, between, after, in, at, through, cistercians, simplest,
# Nearest to d: b, cub, fjords, corsica, esdi, gmbh, nd, van,
# Nearest to no: prism, kiesinger, criticises, not, dedekind, evaluations, any, brotherhoods,
# Nearest to united: latter, accomplishing, nebula, neberg, sequencers, jen, licit, dispersing,
# Nearest to s: erich, whose, subiaco, tumultuous, troppo, transportation, asanga, creationism,
# Nearest to while: subjected, but, where, believe, if, farley, like, triangles,
# Nearest to six: eight, seven, nine, five, four, three, two, zero,
# Nearest to over: walford, olympic, nouveaux, krav, fanon, against, montt, pas,
# Nearest to five: three, four, six, eight, seven, zero, two, nine,
# Average loss at step 22000: 3.500040
# Average loss at step 24000: 3.487945
# Average loss at step 26000: 3.483543
# Average loss at step 28000: 3.478838
# Average loss at step 30000: 3.507625
# Nearest to seven: eight, nine, four, six, five, three, zero, two,
# Nearest to also: generally, often, now, who, still, which, it, largely,
# Nearest to they: there, he, we, it, i, who, not, you,
# Nearest to about: drier, disappointing, syrian, internal, macaulay, bacall, incorporation, exhorted,
# Nearest to most: more, all, theological, some, huis, veterinary, yorke, many,
# Nearest to by: poetess, as, under, in, during, fruitarians, from, with,
# Nearest to state: initiation, city, fernand, culture, fremont, gerhardt, chadian, government,
# Nearest to from: into, in, after, through, between, on, of, cautionary,
# Nearest to d: b, van, fjords, nd, pp, corsica, arming, hemorrhagic,
# Nearest to no: any, little, brotherhoods, not, a, kiesinger, dedekind, prism,
# Nearest to united: accomplishing, latter, neberg, nebula, limb, jen, sequencers, satirised,
# Nearest to s: erich, troppo, his, whose, subiaco, hu, their, puck,
# Nearest to while: believe, where, farley, but, subjected, when, like, is,
# Nearest to six: eight, four, seven, nine, five, three, zero, two,
# Nearest to over: walford, fanon, montt, nouveaux, licit, into, ccds, asis,
# Nearest to five: four, seven, eight, three, six, nine, zero, two,
# Average loss at step 32000: 3.501950
# Average loss at step 34000: 3.493524
# Average loss at step 36000: 3.455630
# Average loss at step 38000: 3.300461
# Average loss at step 40000: 3.426594
# Nearest to seven: eight, five, nine, six, four, three, zero, two,
# Nearest to also: often, usually, which, generally, still, now, guis, largely,
# Nearest to they: we, he, there, you, it, i, not, who,
# Nearest to about: drier, over, disappointing, on, incorporation, internal, tinbergen, syrian,
# Nearest to most: more, many, theological, some, less, veterinary, cei, pap,
# Nearest to by: poetess, solicit, spectre, stansted, curfew, was, with, nominative,
# Nearest to state: government, city, initiation, pitchers, national, chadian, gerhardt, mosquito,
# Nearest to from: through, into, between, deleuze, scrub, after, iraqi, in,
# Nearest to d: b, hemorrhagic, UNK, masonic, nd, gematria, welwyn, campaigned,
# Nearest to no: any, brotherhoods, kiesinger, citizenry, fucked, impediment, prism, than,
# Nearest to united: latter, accomplishing, satirised, jen, neberg, lipi, dispersing, secant,
# Nearest to s: puck, his, chargaff, whose, lito, mets, erich, asu,
# Nearest to while: when, though, although, where, but, like, and, farley,
# Nearest to six: four, five, eight, seven, nine, three, two, zero,
# Nearest to over: about, into, gz, through, fanon, deviations, licit, between,
# Nearest to five: seven, six, four, three, eight, zero, nine, two,
# Average loss at step 42000: 3.435917
# Average loss at step 44000: 3.453184
# Average loss at step 46000: 3.453497
# Average loss at step 48000: 3.355036
# Average loss at step 50000: 3.381728
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to also: often, which, now, actually, generally, usually, guis, then,
# Nearest to they: he, we, there, you, it, she, who, not,
# Nearest to about: drier, incorporation, over, tinbergen, least, disappointing, pollock, gilchrist,
# Nearest to most: more, some, many, use, theological, less, veterinary, huis,
# Nearest to by: poetess, under, pacing, was, fruitarians, through, during, in,
# Nearest to state: initiation, city, chadian, government, photosynthetic, shang, bashing, fremont,
# Nearest to from: into, through, iraqi, after, in, between, cistercians, phony,
# Nearest to d: b, masonic, hemorrhagic, campaigned, donaldson, fjords, nd, h,
# Nearest to no: any, little, fucked, brotherhoods, impediment, than, a, citizenry,
# Nearest to united: latter, satirised, accomplishing, jen, dispersing, neberg, shiraz, secant,
# Nearest to s: whose, chargaff, pindar, his, ghibli, although, erich, and,
# Nearest to while: when, though, but, although, however, where, and, if,
# Nearest to six: eight, seven, four, five, nine, three, two, zero,
# Nearest to over: through, about, fanon, gz, into, on, deviations, walford,
# Nearest to five: six, four, eight, seven, three, zero, nine, two,
# Average loss at step 52000: 3.438587
# Average loss at step 54000: 3.431309
# Average loss at step 56000: 3.439099
# Average loss at step 58000: 3.399160
# Average loss at step 60000: 3.392616
# Nearest to seven: eight, four, six, five, nine, three, zero, one,
# Nearest to also: often, now, usually, actually, generally, still, guis, increasingly,
# Nearest to they: we, there, you, he, it, she, not, i,
# Nearest to about: drier, over, least, bacall, incorporation, on, defies, tinbergen,
# Nearest to most: more, many, some, use, veterinary, helaman, less, all,
# Nearest to by: poetess, through, was, with, container, regaining, hine, using,
# Nearest to state: government, city, initiation, chadian, fremont, photosynthetic, bashing, shang,
# Nearest to from: through, into, within, simplest, after, iraqi, yn, in,
# Nearest to d: b, masonic, h, campaigned, donaldson, hemorrhagic, r, j,
# Nearest to no: any, little, brotherhoods, schloss, citizenry, consistent, lexis, methods,
# Nearest to united: latter, satirised, accomplishing, jen, shiraz, lipi, neberg, dispersing,
# Nearest to s: ratu, twigs, bahasa, whose, advisory, flavours, ranking, sacrificing,
# Nearest to while: when, although, though, however, but, were, if, after,
# Nearest to six: four, eight, five, nine, seven, three, two, zero,
# Nearest to over: through, into, about, between, fanon, troodos, trains, roughly,
# Nearest to five: four, six, three, seven, eight, nine, zero, two,
# Average loss at step 62000: 3.236638
# Average loss at step 64000: 3.257804
# Average loss at step 66000: 3.404092
# Average loss at step 68000: 3.390258
# Average loss at step 70000: 3.363777
# Nearest to seven: six, eight, four, nine, five, three, two, zero,
# Nearest to also: often, now, still, usually, actually, which, largely, generally,
# Nearest to they: we, he, there, you, it, eventually, she, then,
# Nearest to about: over, drier, on, tinbergen, least, bacall, syrian, viaduct,
# Nearest to most: more, some, many, less, veterinary, drugged, use, among,
# Nearest to by: poetess, through, spectre, using, nominative, was, be, intentionally,
# Nearest to state: city, government, chadian, initiation, declaration, gerhardt, photosynthetic, cura,
# Nearest to from: through, into, between, iraqi, in, toward, within, simplest,
# Nearest to d: b, masonic, h, nd, lian, campaigned, hemorrhagic, donaldson,
# Nearest to no: little, any, schloss, sufficient, brotherhoods, consistent, templates, lexis,
# Nearest to united: latter, satirised, accomplishing, shiraz, afterlife, jen, dispersing, lipi,
# Nearest to s: blacklist, bahasa, tahiti, tractate, isaacson, ancillary, ventilated, whose,
# Nearest to while: although, when, though, however, where, including, before, but,
# Nearest to six: eight, four, seven, five, nine, three, zero, two,
# Nearest to over: about, fanon, through, haryana, walford, chime, gz, troodos,
# Nearest to five: four, six, eight, seven, zero, three, nine, two,
# Average loss at step 72000: 3.374300
# Average loss at step 74000: 3.348544
# Average loss at step 76000: 3.319528
# Average loss at step 78000: 3.353737
# Average loss at step 80000: 3.381916
# Nearest to seven: six, eight, five, four, nine, three, zero, one,
# Nearest to also: actually, which, still, often, now, usually, largely, fretted,
# Nearest to they: we, he, there, you, she, eventually, it, these,
# Nearest to about: over, drier, tinbergen, least, bacall, incorporation, cumont, gametes,
# Nearest to most: more, less, many, some, veterinary, among, rhombic, injurious,
# Nearest to by: poetess, and, through, from, poisons, solicit, newly, uss,
# Nearest to state: city, government, chadian, pitchers, gerhardt, photosynthetic, eostre, cura,
# Nearest to from: through, into, after, between, toward, iraqi, across, by,
# Nearest to d: b, masonic, campaigned, te, lian, fujiwara, luxuriant, h,
# Nearest to no: little, any, brotherhoods, lexis, schloss, templates, fucked, perpetuate,
# Nearest to united: latter, shiraz, accomplishing, satirised, jen, afterlife, same, lipi,
# Nearest to s: centric, indemnity, erich, worshippers, neill, ventilated, reconstituted, mara,
# Nearest to while: although, though, when, after, before, including, however, but,
# Nearest to six: seven, four, five, eight, three, nine, two, zero,
# Nearest to over: about, into, between, through, within, fanon, troodos, roughly,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Average loss at step 82000: 3.410345
# Average loss at step 84000: 3.410055
# Average loss at step 86000: 3.388695
# Average loss at step 88000: 3.356108
# Average loss at step 90000: 3.365743
# Nearest to seven: six, eight, five, four, nine, three, zero, two,
# Nearest to also: actually, often, still, usually, now, generally, which, largely,
# Nearest to they: we, he, there, she, you, it, eventually, creationists,
# Nearest to about: drier, over, least, tinbergen, incorporation, syrian, pollock, iso,
# Nearest to most: many, more, some, less, among, use, veterinary, rhombic,
# Nearest to by: poetess, through, with, while, under, during, newly, when,
# Nearest to state: city, government, photosynthetic, gerhardt, cura, chadian, national, eostre,
# Nearest to from: through, into, across, toward, during, after, between, before,
# Nearest to d: b, campaigned, disuse, hemorrhagic, guang, shortwave, nd, du,
# Nearest to no: any, little, fucked, only, brotherhoods, sufficient, mite, already,
# Nearest to united: latter, satirised, accomplishing, shiraz, jen, afterlife, same, lipi,
# Nearest to s: blacklist, ghibli, whose, his, ranking, ariosto, isbn, isaacson,
# Nearest to while: although, when, though, before, after, including, but, and,
# Nearest to six: seven, eight, four, five, nine, three, zero, two,
# Nearest to over: through, about, off, between, within, psychologically, across, sportswriters,
# Nearest to five: seven, eight, four, three, six, nine, zero, two,
# Average loss at step 92000: 3.396972
# Average loss at step 94000: 3.252488
# Average loss at step 96000: 3.356310
# Average loss at step 98000: 3.241238
# Average loss at step 100000: 3.361731
# Nearest to seven: six, eight, four, five, nine, three, zero, two,
# Nearest to also: actually, now, often, still, generally, usually, sometimes, never,
# Nearest to they: we, he, there, you, she, it, eventually, creationists,
# Nearest to about: drier, over, on, iso, incorporation, least, viaduct, approximately,
# Nearest to most: more, less, especially, among, veterinary, many, some, denotation,
# Nearest to by: poetess, when, using, through, woods, during, pacing, poisons,
# Nearest to state: city, government, gerhardt, declaration, cura, chadian, couple, photosynthetic,
# Nearest to from: into, through, in, during, across, after, cautionary, overruled,
# Nearest to d: b, du, relentless, pp, conscientious, te, blackbeard, r,
# Nearest to no: little, any, fucked, only, brotherhoods, lexis, schloss, sufficient,
# Nearest to united: latter, satirised, shiraz, caribbean, accomplishing, afterlife, jen, lipi,
# Nearest to s: whose, his, ariosto, eugen, prefectural, mets, ancillary, ratu,
# Nearest to while: although, when, though, before, and, for, after, where,
# Nearest to six: seven, four, eight, five, nine, three, zero, two,
# Nearest to over: through, about, into, off, across, between, within, haryana,
# Nearest to five: four, seven, six, eight, three, zero, two, nine,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, method='exact')
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
  global data_index
  span = 2 * bag_window + 1 # [ bag_window target bag_window ]
  batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size):
    # just for testing
    buffer_list = list(buffer)
    labels[i, 0] = buffer_list.pop(bag_window)
    batch[i] = buffer_list
    # iterate to the next buffer
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
  data_index = 0
  batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
  print('\nwith bag_window = %d:' % (bag_window))  
  print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
  print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %% [markdown]
# Note the instruction change on the loss function, with reduce_sum to sum the word vectors in the context

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(weights=softmax_weights, biases=softmax_biases, inputs=tf.reduce_sum(embeds, 1),
                               labels=train_labels, num_sampled=num_sampled, num_classes=vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, bag_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.521945
# Nearest to who: unbiased, solar, dominica, ronald, cathay, precede, ccp, rgya,
# Nearest to have: coprime, skit, ncp, declares, starred, healy, vignette, solid,
# Nearest to th: filking, batcave, energized, vilayet, salmonella, mares, defenses, disowned,
# Nearest to from: mandaic, airlines, nfs, lucifer, lateral, boreal, imminent, wilkins,
# Nearest to were: ystem, deities, crocodile, neopaganism, stars, knife, archery, boyle,
# Nearest to its: subjectivity, betting, eileen, duarte, sauerkraut, foremost, rescues, bestseller,
# Nearest to history: guelfs, retailer, nebulae, glidrose, inquire, wonderful, liquids, presto,
# Nearest to four: plata, yogi, scanner, individualized, nva, deserters, vorarlberg, commoners,
# Nearest to i: horned, amateur, fared, multiculturalism, apec, frud, manx, shaggy,
# Nearest to only: impatient, chambre, hexagonal, incursions, rennes, marek, misinterpreted, founders,
# Nearest to was: canaanite, wyman, herschel, edsel, grande, compiler, eclipsed, violate,
# Nearest to no: stv, outsiders, rosters, overlaid, remake, pregnancy, aziz, producer,
# Nearest to years: embryos, sidebar, tg, singaporean, albanian, publicise, ericales, subtitle,
# Nearest to system: shower, shadowed, sidewise, celts, oak, hector, tenerife, deeps,
# Nearest to states: chico, undp, triads, endosymbionts, american, zechariah, pleas, binaries,
# Nearest to would: frontline, ezquerra, between, crystalline, sim, enlisting, fundraiser, committee,
# Average loss at step 2000: 4.591876
# Average loss at step 4000: 3.932109
# Average loss at step 6000: 3.718787
# Average loss at step 8000: 3.535043
# Average loss at step 10000: 3.475903
# Nearest to who: he, she, hirschfeld, rang, retailer, melchizedek, capitan, aeroplane,
# Nearest to have: has, had, be, damme, are, were, excuses, allow,
# Nearest to th: nd, oxidising, adopt, twentieth, gatherings, jenkins, favre, hornets,
# Nearest to from: before, through, mandaic, whipple, dianetics, at, hokku, mensa,
# Nearest to were: are, was, had, grudge, monumental, have, is, bloodstream,
# Nearest to its: their, his, the, straw, tel, her, dispensationalism, any,
# Nearest to history: staunchly, wonderful, stampede, ventricle, induction, refugees, kahane, plunder,
# Nearest to four: eight, five, zero, six, three, seven, nine, two,
# Nearest to i: ii, fortuna, iii, horned, curule, processions, moose, ee,
# Nearest to only: shrubs, paleo, thousand, pueblo, ppp, it, oa, whether,
# Nearest to was: is, were, had, became, has, are, garonne, treasurer,
# Nearest to no: stv, rosters, mutate, serfs, any, lagos, retracted, vfa,
# Nearest to years: days, ships, times, honors, slates, interpretations, species, krzysztof,
# Nearest to system: bethe, donne, precolonial, oak, dispelled, good, jagiellon, shower,
# Nearest to states: kingdom, discontinued, germanic, nations, judgement, banking, symmetry, latitudes,
# Nearest to would: may, will, could, can, should, must, did, to,
# Average loss at step 12000: 3.485087
# Average loss at step 14000: 3.445490
# Average loss at step 16000: 3.436318
# Average loss at step 18000: 3.407101
# Average loss at step 20000: 3.220656
# Nearest to who: which, he, snowman, capitan, melchizedek, tobias, ahasuerus, she,
# Nearest to have: has, had, having, be, are, allow, declares, fortieth,
# Nearest to th: nd, st, twentieth, nine, rd, gatherings, retrospect, toxins,
# Nearest to from: before, through, mensa, whipple, moraine, into, disrespectful, portman,
# Nearest to were: are, was, is, include, became, had, being, have,
# Nearest to its: their, his, her, the, embarrassment, dispensationalism, crudely, funicular,
# Nearest to history: astatine, staunchly, list, yvonne, scanners, examination, pathogenic, instructive,
# Nearest to four: six, five, three, eight, seven, two, zero, nine,
# Nearest to i: ii, we, samara, you, della, geodetic, nostra, dalmatia,
# Nearest to only: doctoral, premiums, menthol, tubular, uga, no, republica, every,
# Nearest to was: is, became, were, discriminated, are, being, had, financed,
# Nearest to no: mutate, any, lagos, flamboyant, stairs, ferus, only, avian,
# Nearest to years: days, year, months, times, height, decades, resolver, slates,
# Nearest to system: systems, jagiellon, seismology, imr, primigenius, outrageous, quota, reisman,
# Nearest to states: kingdom, nations, discontinued, singles, banking, courts, philologists, inwo,
# Nearest to would: should, will, may, could, must, can, might, did,
# Average loss at step 22000: 3.358934
# Average loss at step 24000: 3.295612
# Average loss at step 26000: 3.260759
# Average loss at step 28000: 3.291817
# Average loss at step 30000: 3.221420
# Nearest to who: that, by, he, ahasuerus, interchangeability, cavalcanti, snowman, delighted,
# Nearest to have: has, had, having, were, allow, provide, contain, be,
# Nearest to th: twentieth, nd, nine, rd, dai, carom, beekeeping, st,
# Nearest to from: through, mensa, during, into, before, in, until, mandaic,
# Nearest to were: are, was, include, is, have, manco, ige, had,
# Nearest to its: their, his, her, the, tel, falwell, embarrassment, dispensationalism,
# Nearest to history: modern, alta, list, scanners, stallone, vestigial, diasporas, sagas,
# Nearest to four: five, six, seven, three, nine, eight, zero, two,
# Nearest to i: g, ii, shouted, rene, algernon, geodetic, mail, della,
# Nearest to only: guarantee, lowball, primacy, actually, fifty, archaelogical, first, shrubs,
# Nearest to was: is, became, were, had, are, being, has, discriminated,
# Nearest to no: any, serfs, diagnoses, mineralogy, crank, mutate, lagos, hegel,
# Nearest to years: days, year, months, decades, weeks, times, ccd, centuries,
# Nearest to system: systems, seismology, elven, hopelessly, jagiellon, revocation, ozarks, processes,
# Nearest to states: kingdom, nations, grantham, symmetry, philologists, confiscation, singles, euphrates,
# Nearest to would: could, will, should, may, can, must, might, did,
# Average loss at step 32000: 3.013316
# Average loss at step 34000: 3.205032
# Average loss at step 36000: 3.193175
# Average loss at step 38000: 3.160739
# Average loss at step 40000: 3.170465
# Nearest to who: she, cavalcanti, he, tobias, microscopic, whom, fliers, helicopters,
# Nearest to have: had, has, having, contain, be, allow, give, offer,
# Nearest to th: twentieth, nd, rd, dai, toxins, st, retrospect, nine,
# Nearest to from: through, before, during, into, back, mensa, across, moraine,
# Nearest to were: are, was, include, is, had, various, being, manco,
# Nearest to its: their, his, the, her, your, our, falwell, enamel,
# Nearest to history: antecedents, socially, formulated, crb, skates, philosophy, yunnan, recording,
# Nearest to four: seven, six, five, eight, three, zero, nine, two,
# Nearest to i: ii, g, della, reacted, you, bornholm, kate, axp,
# Nearest to only: raisonn, kilobit, still, equally, drummond, demyelinating, does, wheeler,
# Nearest to was: is, became, were, are, becomes, has, being, remains,
# Nearest to no: any, genscher, winchester, avian, tikal, each, little, reece,
# Nearest to years: days, decades, months, year, weeks, times, centuries, minutes,
# Nearest to system: systems, elven, jagiellon, program, reisman, chrismation, unworkable, revocation,
# Nearest to states: kingdom, nations, confiscation, bryozoa, deed, grantham, bertha, interglacial,
# Nearest to would: will, should, could, must, may, can, might, did,
# Average loss at step 42000: 3.214017
# Average loss at step 44000: 3.143426
# Average loss at step 46000: 3.145324
# Average loss at step 48000: 3.057648
# Average loss at step 50000: 3.062055
# Nearest to who: he, which, docherty, she, fliers, helicopters, tails, offs,
# Nearest to have: has, had, having, contain, include, receive, refer, are,
# Nearest to th: twentieth, nd, rd, nineteenth, st, beekeeping, toxins, nine,
# Nearest to from: through, into, during, within, across, mensa, moraine, since,
# Nearest to were: are, was, being, is, include, have, had, treat,
# Nearest to its: their, his, the, our, her, your, embarrassment, bullets,
# Nearest to history: culture, yunnan, list, modern, ambrosius, haken, origin, reconciling,
# Nearest to four: five, three, six, seven, eight, nine, two, zero,
# Nearest to i: ii, g, pippin, mail, programmers, amphibious, barriers, gildas,
# Nearest to only: immunities, jesu, never, theocratic, even, spices, specified, still,
# Nearest to was: is, were, became, being, becomes, are, discriminated, had,
# Nearest to no: any, little, tikal, rapid, mutate, always, another, reece,
# Nearest to years: days, decades, year, months, weeks, hours, minutes, times,
# Nearest to system: systems, elven, algebras, jagiellon, program, rips, dehydroepiandrosterone, rifle,
# Nearest to states: kingdom, nations, inwo, patriots, suggested, loom, colonies, macy,
# Nearest to would: could, will, should, may, might, can, must, cannot,
# Average loss at step 52000: 3.095964
# Average loss at step 54000: 3.094841
# Average loss at step 56000: 2.919779
# Average loss at step 58000: 3.030810
# Average loss at step 60000: 3.055846
# Nearest to who: willi, breathed, which, chives, reacted, majin, whom, already,
# Nearest to have: had, has, having, include, contain, allow, require, create,
# Nearest to th: twentieth, nd, rd, nineteenth, beekeeping, third, retrospect, nine,
# Nearest to from: through, into, back, mensa, moraine, under, emigrants, between,
# Nearest to were: are, was, is, bracing, projectiles, substituting, being, hezbollah,
# Nearest to its: their, his, her, the, our, embarrassment, your, my,
# Nearest to history: list, origin, modern, existence, science, colony, museum, haken,
# Nearest to four: three, six, seven, five, eight, two, zero, nine,
# Nearest to i: ii, g, nominates, mail, showdown, we, satan, programmers,
# Nearest to only: tidy, unlicensed, doctoral, always, last, never, whether, normative,
# Nearest to was: is, became, were, becomes, had, remained, assur, remains,
# Nearest to no: any, a, little, another, nothing, dryness, genscher, admirable,
# Nearest to years: days, decades, months, year, centuries, weeks, minutes, hours,
# Nearest to system: systems, process, negara, program, layer, elven, entails, language,
# Nearest to states: kingdom, nations, religions, banking, illegality, words, loom, pallium,
# Nearest to would: might, will, could, may, should, can, must, cannot,
# Average loss at step 62000: 3.016141
# Average loss at step 64000: 2.918057
# Average loss at step 66000: 2.940408
# Average loss at step 68000: 2.963047
# Average loss at step 70000: 3.007083
# Nearest to who: he, already, which, grapevine, seyss, whose, risings, arabidopsis,
# Nearest to have: had, has, having, contain, include, create, offer, allow,
# Nearest to th: twentieth, nd, rd, st, nineteenth, nine, beekeeping, retrospect,
# Nearest to from: through, before, back, mensa, moraine, after, disrespectful, across,
# Nearest to were: are, was, is, had, substituting, newly, be, been,
# Nearest to its: their, his, our, her, the, your, embarrassment, dandies,
# Nearest to history: origin, existence, origins, nature, course, concept, list, colony,
# Nearest to four: five, three, seven, six, two, eight, backhand, circumvented,
# Nearest to i: g, ii, we, you, mail, ahimelech, ht, v,
# Nearest to only: always, typically, actually, formally, even, personification, premiums, herons,
# Nearest to was: is, were, became, becomes, are, makes, assur, had,
# Nearest to no: genscher, nothing, any, moria, eigenstates, terminals, purports, quartered,
# Nearest to years: decades, days, months, weeks, hours, minutes, year, centuries,
# Nearest to system: systems, situation, unsophisticated, contract, formats, gratitude, rifle, program,
# Nearest to states: kingdom, nations, patriots, banking, state, loom, singles, impressive,
# Nearest to would: will, may, could, should, might, must, can, cannot,
# Average loss at step 72000: 2.930391
# Average loss at step 74000: 2.866499
# Average loss at step 76000: 2.997909
# Average loss at step 78000: 3.007563
# Average loss at step 80000: 2.847233
# Nearest to who: whom, which, unwise, already, grapevine, willi, risings, breathed,
# Nearest to have: had, has, having, contain, offer, create, remain, include,
# Nearest to th: twentieth, nd, st, rd, nineteenth, nine, third, beekeeping,
# Nearest to from: through, back, across, into, via, mensa, disrespectful, since,
# Nearest to were: are, was, is, include, have, had, various, treat,
# Nearest to its: their, his, her, our, the, your, my, s,
# Nearest to history: list, origins, study, origin, existence, treaty, concept, discussion,
# Nearest to four: six, five, three, seven, eight, zero, nine, two,
# Nearest to i: ii, g, iii, you, mail, claire, we, ahimelech,
# Nearest to only: always, hyllus, venom, pregnant, just, personification, consistory, premiums,
# Nearest to was: is, were, becomes, became, are, had, makes, discriminated,
# Nearest to no: nothing, any, little, moria, dryness, genscher, admirable, stairs,
# Nearest to years: decades, months, days, weeks, minutes, centuries, hours, year,
# Nearest to system: systems, status, program, contract, principle, situation, sleeves, constitution,
# Nearest to states: kingdom, nations, state, banking, churches, religions, provinces, workers,
# Nearest to would: could, will, might, should, must, may, can, cannot,
# Average loss at step 82000: 2.935455
# Average loss at step 84000: 2.904099
# Average loss at step 86000: 2.918940
# Average loss at step 88000: 2.938139
# Average loss at step 90000: 2.828871
# Nearest to who: whom, which, collectivist, unwise, organisers, ronnie, granularity, enniskillen,
# Nearest to have: has, had, having, represent, contain, include, produce, allow,
# Nearest to th: twentieth, nd, st, nineteenth, beekeeping, rd, fourth, nine,
# Nearest to from: back, into, mensa, between, through, across, during, screwtape,
# Nearest to were: are, was, is, represent, include, be, treat, have,
# Nearest to its: their, his, the, her, whose, our, your, my,
# Nearest to history: list, republic, study, collection, course, version, period, origin,
# Nearest to four: six, five, three, eight, seven, two, zero, nine,
# Nearest to i: g, ii, mail, ahimelech, lung, quickest, intrepid, we,
# Nearest to only: always, no, demyelinating, ever, actually, taiga, intelligibility, mutate,
# Nearest to was: is, were, became, becomes, had, are, has, remains,
# Nearest to no: nothing, little, moria, any, only, another, electrophoresis, stairs,
# Nearest to years: decades, months, days, weeks, hours, minutes, centuries, year,
# Nearest to system: systems, seedless, squatters, process, formats, principle, structure, fractions,
# Nearest to states: kingdom, nations, religions, loom, illegality, suggested, companies, feasible,
# Nearest to would: will, could, might, should, may, must, can, cannot,
# Average loss at step 92000: 2.900810
# Average loss at step 94000: 2.880518
# Average loss at step 96000: 2.706897
# Average loss at step 98000: 2.460841
# Average loss at step 100000: 2.707094
# Nearest to who: whom, which, he, responsible, hirschfeld, actually, dominica, unwise,
# Nearest to have: had, has, having, contain, represent, include, produce, allow,
# Nearest to th: twentieth, nd, nineteenth, rd, st, fourth, fifteenth, fifth,
# Nearest to from: into, across, through, mensa, between, beyond, via, back,
# Nearest to were: are, was, have, had, is, overwriting, unifies, include,
# Nearest to its: their, his, her, your, the, dispensationalism, our, my,
# Nearest to history: course, jews, list, origin, collection, jehoram, interpretation, version,
# Nearest to four: three, seven, five, six, eight, zero, two, nine,
# Nearest to i: ii, g, we, mail, iii, showdown, quickest, algernon,
# Nearest to only: always, first, enough, exception, universally, no, neologisms, sixth,
# Nearest to was: is, became, were, are, exists, makes, remains, had,
# Nearest to no: little, nothing, any, electrophoresis, another, dryness, genscher, moria,
# Nearest to years: decades, months, weeks, days, year, hours, centuries, minutes,
# Nearest to system: systems, program, station, seedless, model, contract, unit, process,
# Nearest to states: kingdom, nations, state, deed, aphorisms, chiefs, patriots, workers,
# Nearest to would: could, will, might, should, must, can, may, did,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
